# %% [markdown]
# <a href="https://colab.research.google.com/github/Supraja1419/Supraja_INFO5731_spring2023/blob/main/In_class_exercise_Supraja_B_02_02072023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (02/07/2023, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

Finding out how social media affects people's mental health is an intriguing study question that comes to mind.

To provide a response, the following information would need to be gathered:
1.Information on demographics (age, gender, location, etc.)
data about social media usage (frequency of use, platforms used, etc.)
Information on mental health (depression scale scores, anxiety scores, etc.)
Additional relevant data that might exist (employment status, relationship status, etc.)
For the analysis, approximately 1000 data samples would be required.

Procedures for gathering and storing the data:
Create a survey questionnaire with all the necessary information on it.
Distribute the survey to a sample of people who represent the entire population.
Gather the responses and keep them in a database or spreadsheet for analysis.



'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):



# !pip install scholarly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 64.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 KB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 KB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 17.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 KB 39.8 MB/s eta 0:00:00
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

def collect_data_samples():
   data = []
   for i in range(1000):
       # Code to collect individual data sample goes here
       def main():
        age = 0;
        gender = 0;
        location = " ";
        getAge();
        getWeight();
        getBirth();
        correct();

def getAge():
    age = input("Guess the age.\t")
    return age;
def getWeight():
    weight = input("Guess the weight.\t")
    return weight;
def getBirth():
    birthMonth = input("Guess the month.\t")
    return birthMonth;
def correct():
    if (age <= 25):
         print ("Congratulations, the age is 25 or less")
    else:
        print ("You did not correctly guess the age");
    if (weight <= 128):
        print ("Congratulations, the weight is 128 or more")
    else:
        print ("You did not correctly guess the weight");
    if (birthMonth == 25):
        print ("Congratulations, the month is April")
    else:
        print ("You did not correctly guess the month");
main();
data = collect_data_samples()
df = pd.DataFrame(data)
df.to_csv("data_samples.csv", index=False)

df.head()
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d0cf4094c338> in <module>
#      38     else:
#      39         print ("You did not correctly guess the month");
# ---> 40 main();
#      41 data = collect_data_samples()
#      42 df = pd.DataFrame(data)
#
# NameError: name 'main' is not defined

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):
#Importing  libraries 
import json as j
import urllib.request as request
from bs4 import BeautifulSoup as beauty
#accessing the URL
with request.urlopen('https://api.semanticscholar.org/v1/paper/10.1145/2348283.2348407') as fileread:
    page_g = fileread.read()
    slight_p = beauty(page_g)
    print(slight_p.p.text)
    with open('output.txt', 'w') as filewrite:
        j.dump(slight_p.p.text, filewrite)
# Out:
# {"abstract":"Typically, every part in most coherent text has some plausible reason for its presence, some function that it performs to the overall semantics of the text. Rhetorical relations, e.g. contrast, cause, explanation, describe how the parts of a text are linked to each other. Knowledge about this so-called discourse structure has been applied successfully to several natural language processing tasks. This work studies the use of rhetorical relations for Information Retrieval (IR): Is there a correlation between certain rhetorical relations and retrieval performance? Can knowledge about a document's rhetorical relations be useful to IR? We present a language model modification that considers rhetorical relations when estimating the relevance of a document to a query. Empirical evaluation of different versions of our model on TREC settings shows that certain rhetorical relations can benefit retrieval effectiveness notably (>10% in mean average precision over a state-of-the-art
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# You code here (Please add comments in the code):

import pandas as pd
import numpy as np
import tweepy
from tweepy import OAuthHandler
import requests
import json


key= '2Em7SxlX9jPMfL4x97r3zMO0x'
secret= 'sVbJzekKuiAgq83Y7gCwNVbSowqQokGVzWexKHl2cXIPceWtSd'
token= '1439767876962029572-uUMt8oWRyzj9ilE5zk4uYbL93sCMPT'
token_secret= 'oydIGymn9bS767FVEMawE9GyGAnMmBJfaY2XXKmHnmliF'



# Authenticate to Twitter API
auth = tweepy.OAuthHandler(key, secret)
auth.set_access_token(token,token_secret)

# Create API object
api = tweepy.API(auth)

# Collect 1000 tweets
tweets = api.search(q="#love", count=1000)

# Store the information in a list
posts = []
for tweet in tweets:
    user_name = tweet.user.screen_name
    posted_time = tweet.created_at
    text = tweet.text
    posts.append({"User Name": user_name, "Posted Time": posted_time, "Text": text})

# Print the list of posts
for post in posts:
    print("User Name:", post["User Name"])
    print("Posted Time:", post["Posted Time"])
    print("Text:", post["Text"])
    print("\n")
# Out:
# User Name: JoelleMasiaGTI
# Posted Time: 2023-02-15 21:46:15
# Text: RT @MaykiGTI: 🔥👂LISTEN TO👂THIS SOUND MY FRIEND😉🔥
#
# 👑🎵@NICKIMINAJ ft @Mr_Camron @RickRoss🎵👑
#
# 🎶I Am Your Leader🎶Full👇🚨HIT !!!🚨
# https://t.co/96…
#
#
# User Name: baby_freyja
# Posted Time: 2023-02-15 21:46:13
# Text: RT @RappCatsAdopt: 🎉Lillie has an application! Stay tuned! All paws crossed for this little girl getting adopted! #cat #cats #kitten #kitte…
#
#
# User Name: IhateDono
# Posted Time: 2023-02-15 21:46:10
# Text: RT @coobles321: My prayers go out to those who loss their lives And to all the Spartan  Community GO Green. #love #hope #gogreen #weareone…
#
#
# User Name: Marietta117
# Posted Time: 2023-02-15 21:46:06
# Text: Great day dear friends 💕 look at this wonderful #orchid so huge and beautiful 🌸 #NewBloom #orchidsoftwitter #love… https://t.co/kFlkXfxwai
#
#
# User Name: Winelkrows
# Posted Time: 2023-02-15 21:46:04
# Text: RT @lucywolf18: First meet (N°2)
# ❤️ Feliz día del amor y la amistad❤️
# ...
